# %% [markdown]
# # Pretrained Models - Kunskapskontroll

# %% [markdown]
# **Obligatoriskt att fylla i uppgifterna nedan.**
#
# Namn: Adrian Krsmanovic
#
# Vem du har presenterat för: Keiket & Sebastian
#
# Datum då du presenterade: 2024-05-08
#
# **Kunskapskontrollen lämnas in på Omniway.**

# %% [markdown]
# **It is possible to load pretrained models which is a powerful concept.**

# %% [markdown]
# Model implementation:
# https://keras.io/api/applications/#usage-examples-for-image-classification-models
#
# Class list for ResNet50, for example tennis ball is 852:
# https://deeplearning.cms.waikato.ac.nz/user-guide/class-maps/IMAGENET/

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np
from PIL import Image

# %%
model = ResNet50(weights='imagenet')

# %%
img_path = 'zebra.jpg'
# img_path = 'linjal.jpg'
# img_path = 'tennisboll.jpg'
img = image.load_img(img_path, target_size=(224, 224))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x = image.img_to_array(img)
x.shape
# Out:
# (224, 224, 3)

# %%
x = np.expand_dims(x, axis=0)
x.shape
# Out:
# (1, 224, 224, 3)

# %%
# https://www.tensorflow.org/api_docs/python/tf/keras/applications/resnet50/preprocess_input
x = preprocess_input(x)

# %%
preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Predicted: [(u'n02504013', u'Indian_elephant', 0.82658225), (u'n01871265', u'tusker', 0.1122357), (u'n02504458', u'African_elephant', 0.061040461)]
# Out:
# 1/1 [==============================] - 3s 3s/step
# Predicted: [('n02391049', 'zebra', 0.986429), ('n02423022', 'gazelle', 0.0034323514), ('n01798484', 'prairie_chicken', 0.002942116)]

# %% [markdown]
# # 1. Take some pictures yourself and predict their class.

# %% [markdown]
# Remove # for the image you want to use and run code. To change image restore hashtag and remove for wanted picture

# %%
# banana
# im_path = 'img_banan.jpeg'

# dog english springer spaniel
im_path = 'img_hund1.jpeg'

# Soccerball
# im_path = 'img_soccer.jpg'

img_1 = img = image.load_img(im_path, target_size=(224, 224))
img_1 = img_1.rotate(-90)
img_1
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x_1 = image.img_to_array(img_1)
x_1.shape
# Out:
# (224, 224, 3)

# %%
x_1 = np.expand_dims(x_1, axis=0)
x_1.shape
# Out:
# (1, 224, 224, 3)

# %%
#förbehandlar bilden för att matcha resnet-50 bilder.
x_1 = preprocess_input(x_1)

# %%
pred = model.predict(x_1)
#get top 3 probalities 
print('Predicted:', decode_predictions(pred, top=3)[0])
# Out:
# 1/1 [==============================] - 0s 22ms/step
# Predicted: [('n02102040', 'English_springer', 0.9496941), ('n02101388', 'Brittany_spaniel', 0.035626248), ('n02102318', 'cocker_spaniel', 0.004196271)]

# %% [markdown]
# # 2. Answer the question: Why is "Pretrained models" a very powerful concept?

# %% [markdown]
# Because pretrained models allows us to use an existing model for our own problems without training a new model, This is very useful and powerful since we do not need our own data to create a new model. Deep learning often requires lots of data and time and therefore using a pretrained model can save both time and resource.
